# %% [markdown]
# #Data Toolkit

# %% [markdown]
# 1. What is NumPy, and why is it widely used in Python?
#
# NumPy is a Python library used for fast numerical computing. It provides powerful multi-dimensional arrays and mathematical functions. It’s widely used because it makes calculations faster and easier than using normal Python lists.
#
# 2. How does broadcasting work in NumPy?
#
# Broadcasting lets NumPy perform operations on arrays of different shapes by automatically expanding smaller arrays to match larger ones — without making extra copies.
#
# 3. What is a Pandas DataFrame?
#
# A DataFrame is a 2D table of data with labeled rows and columns, like an Excel sheet. It’s used for storing and analyzing structured data.
#
# 4. Explain the use of the groupby() method in Pandas?
#
# groupby() groups data based on one or more columns and allows you to apply functions like sum, mean, or count to each group separately.
#
# 5. Why is Seaborn preferred for statistical visualizations?
#
# Seaborn makes it easy to create attractive and informative charts. It’s built on Matplotlib and is great for showing data relationships and patterns with less code.
#
# 6. Differences between NumPy arrays and Python lists:
#
# NumPy arrays are faster, store one data type, and support math operations directly. Python lists are slower, can hold mixed data, and need loops for math.
#
# 7. What is a heatmap, and when should it be used?
#
# A heatmap shows data values as colors in a grid. It’s used to spot patterns or correlations in large datasets, like a correlation matrix.
#
# 8. What does “vectorized operation” mean in NumPy?
#
# It means performing calculations on entire arrays at once instead of using loops, making the code faster and shorter.
#
# 9. How does Matplotlib differ from Plotly?
#
# Matplotlib makes static (non-interactive) plots. Plotly makes interactive, web-based charts that you can zoom or hover over.
#
# 10. Significance of hierarchical indexing in Pandas:
#
# It allows multiple levels of indexing (like country → year) so you can easily handle and analyze complex, multi-level data.
#
# 11. Role of Seaborn’s pairplot() function:
#
# pairplot() shows relationships between all pairs of variables in one chart using scatter plots and histograms — great for exploring data.
#
# 12. Purpose of the describe() function in Pandas:
#
# It gives quick summary statistics (count, mean, min, max, etc.) of numeric columns in a DataFrame.
#
# 13. Why is handling missing data important in Pandas?
#
# Missing data can lead to wrong results. Handling it ensures your analysis is correct and reliable.
#
# 14. Benefits of using Plotly for visualization:
#
# Plotly creates interactive, beautiful, and web-ready charts easily. It’s great for dashboards and data exploration.
#
# 15. How does NumPy handle multidimensional arrays?
#
# NumPy stores data in n-dimensional arrays (1D, 2D, 3D, etc.) and allows easy slicing, reshaping, and operations across dimensions.
#
# 16. Role of Bokeh in data visualization:
# Bokeh helps build interactive, real-time charts and dashboards for the web using Python.
#
# 17. Explain the difference between apply() and map() in Pandas:
#
# map() is used to apply a function element-wise to a Series.
#
# apply() can be used on both DataFrame and Series to apply a function along rows or columns.
#
# 📘 Example:
#
# df['col'].map(str.upper)      # Works on Series
# df.apply(sum, axis=0)         # Works on DataFrame
#
#
# 18. What are some advanced features of NumPy:
#
# Broadcasting
#
# Vectorized operations
#
# Linear algebra and FFT functions
#
# Random number generation
#
# Memory-efficient multi-dimensional arrays
#
# 19. How does Pandas simplify time series analysis:
#
# Built-in date and time functions
#
# Easy resampling and frequency conversion
#
# Rolling and shifting operations
#
# Automatic handling of datetime indexes
#
# 20. What is the role of a pivot table in Pandas:
#
# Summarizes data for better analysis.
#
# Helps group, aggregate, and rearrange data by specific columns.
#
# 📘 Example:
#
# pd.pivot_table(df, values='Sales', index='Month', columns='Region')
#
#
# 21. Why is NumPy’s array slicing faster than Python’s list slicing:
#
# NumPy arrays store data in contiguous memory,
#
# Operations are done in C (low-level language), making them much faster than Python lists.
#
# 22. What are some common use cases for Seaborn:
#
# Visualizing relationships between variables (e.g., scatterplot, pairplot)
#
# Creating statistical plots (e.g., boxplot, violinplot)
#
# Drawing heatmaps and distribution plots
#
# Enhancing visual appearance of Matplotlib charts
